# %%
import pandas as pd
#used for datastructures and dataframes
path = "D:/TUTEDUDE/DateAnalysis/auto-mpg.csv"
#df=dataframe
df = pd.read_csv(path)
#df = pd.read_csv(path, headers = None)
print(df)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.head(5)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.tail(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin         car name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
df.to_csv(path) #TO SAVE THE FILE

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.describe(include="all")
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN        150          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  model year      origin    car name
# count     398.000000  398.000000  398.000000         398
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
import pandas as pd
path = "D:/TUTEDUDE/DateAnalysis/data.xlsx"
df1=pd.read_excel(path)
print(df1)
# Out:
#     S. No.     A   B   C     D   E
# 0        1   2.0   1   5   3.0   4
# 1        2   4.0   3  10   6.0   8
# 2        3   6.0   5  15   9.0  12
# 3        4   8.0   7  20  12.0  16
# 4        5  10.0   9  25  15.0  20
# 5        6  12.0  11  30  18.0  24
# 6        7  14.0  13  35  21.0  28
# 7        8  16.0  15  40  24.0  32
# 8        9  18.0  17  45  27.0  36
# 9       10  20.0  19  50  30.0  40
# 10      11   NaN  21  55   NaN  44

# %%
df1.head(5)
# Out:
#    S. No.     A  B   C     D   E
# 0       1   2.0  1   5   3.0   4
# 1       2   4.0  3  10   6.0   8
# 2       3   6.0  5  15   9.0  12
# 3       4   8.0  7  20  12.0  16
# 4       5  10.0  9  25  15.0  20

# %%
headers=["S.No.","EVEN","ODD","Multiples 5", "Multiples 3", "Multiples 4"]
df1.columns=headers
df1.head(5)
# Out:
#    S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 4
# 0      1   2.0    1            5          3.0            4
# 1      2   4.0    3           10          6.0            8
# 2      3   6.0    5           15          9.0           12
# 3      4   8.0    7           20         12.0           16
# 4      5  10.0    9           25         15.0           20

# %%
print(df1)
# Out:
#     S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 4
# 0       1   2.0    1            5          3.0            4
# 1       2   4.0    3           10          6.0            8
# 2       3   6.0    5           15          9.0           12
# 3       4   8.0    7           20         12.0           16
# 4       5  10.0    9           25         15.0           20
# 5       6  12.0   11           30         18.0           24
# 6       7  14.0   13           35         21.0           28
# 7       8  16.0   15           40         24.0           32
# 8       9  18.0   17           45         27.0           36
# 9      10  20.0   19           50         30.0           40
# 10     11   NaN   21           55          NaN           44

# %%
df1["ODD"]=df1["ODD"]+1
df1.head(5)
# Out:
#    S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 4
# 0      1   2.0    2            5          3.0            4
# 1      2   4.0    4           10          6.0            8
# 2      3   6.0    6           15          9.0           12
# 3      4   8.0    8           20         12.0           16
# 4      5  10.0   10           25         15.0           20

# %%
df1["ODD"]=df1["ODD"]-1
df1.head(5)
# Out:
#    S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 4
# 0      1   2.0    1            5          3.0            4
# 1      2   4.0    3           10          6.0            8
# 2      3   6.0    5           15          9.0           12
# 3      4   8.0    7           20         12.0           16
# 4      5  10.0    9           25         15.0           20

# %%
print(df1)
# Out:
#     S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 4
# 0       1   2.0    1            5          3.0            4
# 1       2   4.0    3           10          6.0            8
# 2       3   6.0    5           15          9.0           12
# 3       4   8.0    7           20         12.0           16
# 4       5  10.0    9           25         15.0           20
# 5       6  12.0   11           30         18.0           24
# 6       7  14.0   13           35         21.0           28
# 7       8  16.0   15           40         24.0           32
# 8       9  18.0   17           45         27.0           36
# 9      10  20.0   19           50         30.0           40
# 10     11   NaN   21           55          NaN           44

# %%
df1.drop([10],axis=0) #axis=1 is column and #axis=0 is a row.
# Out:
#    S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 4
# 0      1   2.0    1            5          3.0            4
# 1      2   4.0    3           10          6.0            8
# 2      3   6.0    5           15          9.0           12
# 3      4   8.0    7           20         12.0           16
# 4      5  10.0    9           25         15.0           20
# 5      6  12.0   11           30         18.0           24
# 6      7  14.0   13           35         21.0           28
# 7      8  16.0   15           40         24.0           32
# 8      9  18.0   17           45         27.0           36
# 9     10  20.0   19           50         30.0           40

# %%
print(df1)
# Out:
#     S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 4
# 0       1   2.0    1            5          3.0            4
# 1       2   4.0    3           10          6.0            8
# 2       3   6.0    5           15          9.0           12
# 3       4   8.0    7           20         12.0           16
# 4       5  10.0    9           25         15.0           20
# 5       6  12.0   11           30         18.0           24
# 6       7  14.0   13           35         21.0           28
# 7       8  16.0   15           40         24.0           32
# 8       9  18.0   17           45         27.0           36
# 9      10  20.0   19           50         30.0           40
# 10     11   NaN   21           55          NaN           44

# %%
df1.dropna()
# Out:
#    S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 4
# 0      1   2.0    1            5          3.0            4
# 1      2   4.0    3           10          6.0            8
# 2      3   6.0    5           15          9.0           12
# 3      4   8.0    7           20         12.0           16
# 4      5  10.0    9           25         15.0           20
# 5      6  12.0   11           30         18.0           24
# 6      7  14.0   13           35         21.0           28
# 7      8  16.0   15           40         24.0           32
# 8      9  18.0   17           45         27.0           36
# 9     10  20.0   19           50         30.0           40

# %%
df1.dropna(subset = ["EVEN"],axis=0)
# Out:
#    S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 4
# 0      1   2.0    1            5          3.0            4
# 1      2   4.0    3           10          6.0            8
# 2      3   6.0    5           15          9.0           12
# 3      4   8.0    7           20         12.0           16
# 4      5  10.0    9           25         15.0           20
# 5      6  12.0   11           30         18.0           24
# 6      7  14.0   13           35         21.0           28
# 7      8  16.0   15           40         24.0           32
# 8      9  18.0   17           45         27.0           36
# 9     10  20.0   19           50         30.0           40

# %%
import numpy as np
df1["EVEN"].replace(np.nan,22)
# Out:
# 0      2.0
# 1      4.0
# 2      6.0
# 3      8.0
# 4     10.0
# 5     12.0
# 6     14.0
# 7     16.0
# 8     18.0
# 9     20.0
# 10    22.0
# Name: EVEN, dtype: float64

# %%
df1["Multiples 4"]=df1["Multiples 4"]/2

# %%
df1.head(5)
# Out:
#    S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 4
# 0      1   2.0    1            5          3.0          2.0
# 1      2   4.0    3           10          6.0          4.0
# 2      3   6.0    5           15          9.0          6.0
# 3      4   8.0    7           20         12.0          8.0
# 4      5  10.0    9           25         15.0         10.0

# %%
df1.rename(columns={"Multiples 4":"Multiples 2"})
# Out:
#     S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 2
# 0       1   2.0    1            5          3.0          2.0
# 1       2   4.0    3           10          6.0          4.0
# 2       3   6.0    5           15          9.0          6.0
# 3       4   8.0    7           20         12.0          8.0
# 4       5  10.0    9           25         15.0         10.0
# 5       6  12.0   11           30         18.0         12.0
# 6       7  14.0   13           35         21.0         14.0
# 7       8  16.0   15           40         24.0         16.0
# 8       9  18.0   17           45         27.0         18.0
# 9      10  20.0   19           50         30.0         20.0
# 10     11   NaN   21           55          NaN         22.0

# %%
df1.dtypes
# Out:
# S.No.            int64
# EVEN           float64
# ODD              int64
# Multiples 5      int64
# Multiples 3    float64
# Multiples 4    float64
# dtype: object

# %%
df1.drop([10],axis=0)
# Out:
#    S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 4
# 0      1   2.0    1            5          3.0          2.0
# 1      2   4.0    3           10          6.0          4.0
# 2      3   6.0    5           15          9.0          6.0
# 3      4   8.0    7           20         12.0          8.0
# 4      5  10.0    9           25         15.0         10.0
# 5      6  12.0   11           30         18.0         12.0
# 6      7  14.0   13           35         21.0         14.0
# 7      8  16.0   15           40         24.0         16.0
# 8      9  18.0   17           45         27.0         18.0
# 9     10  20.0   19           50         30.0         20.0

# %%
df1.rename(columns={"Multiples 4":"Multiples 2"}, inplace = True)

# %%
df1.head(5)
# Out:
#    S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 2
# 0      1   2.0    1            5          3.0          2.0
# 1      2   4.0    3           10          6.0          4.0
# 2      3   6.0    5           15          9.0          6.0
# 3      4   8.0    7           20         12.0          8.0
# 4      5  10.0    9           25         15.0         10.0

# %%
df1.dtypes
# Out:
# S.No.            int64
# EVEN           float64
# ODD              int64
# Multiples 5      int64
# Multiples 3    float64
# Multiples 2    float64
# dtype: object

# %% [markdown]
# f

# %%
df1["Multiples 2"]=df1["Multiples 2"].astype("int")

# %%
df1.dtypes
# Out:
# S.No.            int64
# EVEN           float64
# ODD              int64
# Multiples 5      int64
# Multiples 3    float64
# Multiples 2      int32
# dtype: object

# %%
df1.head(10)
# Out:
#    S.No.  EVEN  ODD  Multiples 5  Multiples 3  Multiples 2
# 0      1   2.0    1            5          3.0            2
# 1      2   4.0    3           10          6.0            4
# 2      3   6.0    5           15          9.0            6
# 3      4   8.0    7           20         12.0            8
# 4      5  10.0    9           25         15.0           10
# 5      6  12.0   11           30         18.0           12
# 6      7  14.0   13           35         21.0           14
# 7      8  16.0   15           40         24.0           16
# 8      9  18.0   17           45         27.0           18
# 9     10  20.0   19           50         30.0           20
